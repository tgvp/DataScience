# %% [markdown]
# # Lab 1 - Python
#
# ## Purpose
# The purpose of this notebook is to make you more confident coding with Python and Jupyter Notebooks, which we will be using for the rest of the year (also in the second semester in Inteligência Artificial).
#
# ## Methodology
# Review basic operations, data types and programming concepts in Python. Solve programming challenges.
#
# ## Results
# Fast track to programming in Python.
#
# ---

# %% [markdown]
# ## Setup
#
# ### Library import

# %%
#importar biblioteca numpy
#para esse caso usa-se um alias para o numpy. Isso significa que quando se quiser usar "numpy" basta digitar "np"
import numpy as np

# %% [markdown]
# #### Numpy

# %% [markdown]
# The fundamental package for scientific computing with Python
#
# <img src="https://numpy.org/images/logo.svg" width="100" height="100">
#
# [NumPy](https://numpy.org/)

# %% [markdown]
# ---
#
# # Review

# %% [markdown]
# ## Types

# %% [markdown]
# https://docs.python.org/3.6/library/stdtypes.html

# %% [markdown]
# ### Boolean

# %%
#python possui tipos boleanos
True

#criando uma variavel bool chamada a
a = True
#imprimir o tipo de a
print(type(a))


#criando uma variavel bool chamada b
b = False
#imprimir o tipo de b
print(type(b))
# Out:
# <class 'bool'>

# %% [markdown]
# #### Boolean Operations
#
# Suppose variables `x` and `y`
#
#
# <table><thead>
# <tr>
# <th style="text-align: center">Operator</th>
# <th>Description</th>
# <th>Code</th>
# </tr>
# </thead><tbody>
# <tr>
# <td style="text-align: center">and</td>
# <td>True if both are true</td>
# <td><code>x and y</code></td>
# </tr>
# <tr>
# <td style="text-align: center">or</td>
# <td>True if at least one is true</td>
# <td><code>x or y</code></td>
# </tr>
# <tr>
# <td style="text-align: center">not</td>
# <td>True only if false</td>
# <td><code>not x</code></td>
# </tr>
# </tbody></table>

# %%
#para testar os operadores acima cria-se uma variável x e y
x = True
y = False

# %%
#resultado de x and y
x and y
# Out:
# False

# %%
#resultado de x or y
x or y
# Out:
# True

# %%
#utilizando o operador not
x and not y
# Out:
# True

# %% [markdown]
# ---
#
# ###  Numeric
# - int
# - float

# %%
#para criar um tipo inteiro basta atribuir um número inteiro
a_integer = 2
type(a_integer)
# Out:
# int

# %%
#para criar um tipo float basta atribuir um número float
a_float = 2.0
type(a_float)
# Out:
# float

# %% [markdown]
# Cast from Float to Integer

# %%
#é possivel extrair a parte inteira de um float
int(2.0)
# Out:
# 2

# %% [markdown]
# Cast from Integer to Float

# %%
#também é possivel transformar um inteiro em float
float(2)
# Out:
# 2.0

# %% [markdown]
# ---

# %% [markdown]
# ### Sequence Types

# %% [markdown]
# #### Text Sequence or String

# %%
#strings podem ser atribuidos passando um dato no formato de texto seja entre aspas simples ou duplas
a_string = "Data"
b_string = 'Data'

#imprimindo o teste se os dois strings sao iguais
print(a_string==b_string)

#chegando o tipo da variável
print(type(a_string))
# Out:
# True
# <class 'str'>

# %% [markdown]
# Concatenate Strings

# %%
#para concatenar strings basta usar o operador "+"
a_string + " Science"
# Out:
# 'Data Science'

# %% [markdown]
# #### List,  Mutable Dynamic Arrays

# %% [markdown]
# Empty List

# %%
#para criar uma lista basta utilizar os parênteses retos
list_array = []

print(type(list_array))
# Out:
# <class 'list'>

# %% [markdown]
# Multiple types

# %%
#lista pode ter multiplos tipos
#no caso abaixo é uma lista de strings, numeros inteiros e numeros float
list_array = ["one", "two", 3, 4.0]

list_array
# Out:
# ['one', 'two', 3, 4.0]

# %% [markdown]
# Mutability

# %%
#dados de uma lista podem ser acessados passando o endereço dentro de um parentese reto
#listas também podem ser modificadas usando o operador "="
list_array[1] = "A"

list_array
# Out:
# ['one', 'A', 3, 4.0]

# %% [markdown]
# Append at the end

# %%
#para adicionar um novo item no final da lista basta usar método append()
#adicionado novos dados abaixo
list_array.append("Data")
list_array.append("Science")
list_array.append("Intro")
list_array.append(10)

#imprimindo a lista com os novos dados
list_array
# Out:
# ['one', 'A', 3, 4.0, 'Data', 'Science', 'Intro', 10]

# %% [markdown]
# Remove at the end

# %%
#para remover um intem de uma lista usa-se o pop
#se não passar paramentro dentro do parentes ele remove o ultimo item
#o pop sempre retorna o item que foi removido da lista
removido = list_array.pop()
print(removido)

list_array
# Out:
# 10
# ['one', 'A', 3, 4.0, 'Data', 'Science', 'Intro']

# %%
#é possivel passar o endereço dentro do parenteses para remover um item e específico
#o pop sempre retorna o item que foi removido da lista
removido = list_array.pop(2)
print(removido)
# Out:
# 3

# %% [markdown]
# Remove Operation by index

# %%
#há também a funcao del
del list_array[1]
list_array
# Out:
# ['one', 4.0, 'Data', 'Science', 'Intro']

# %% [markdown]
# Size of list

# %%
#para saber o tamanho de uma lista ou de um objeto usa-se a função len()
len(list_array)
# Out:
# 5

# %% [markdown]
# Acessing list elements

# %%
#como listado acima é possivel acessar um item da lista através de seu endereço
list_array[0]
# Out:
# 'one'

# %%
#É possivel usar também endereços negativos para acessar a lista de tras para frente.
#Da esquerda para direita os endereços iniciam em 0 até n-1
#Da direita para esquerda os enderenços iniciam em -1 até -n
list_array[-1]
# Out:
# 5
# 'one'

# %% [markdown]
# Indexing or **Slicing** List

# %% [markdown]
# ```python
# start:end(exclusive):step
# ```

# %% [markdown]
# From first to second, all values

# %%
#print de todos os valores da lista
list_array
# Out:
# ['one', 4.0, 'Data', 'Science', 'Intro']

# %% [markdown]
# From first to last, every two values

# %%
#É possivel usar valores negativos
#O "0" no endereço inicial também pode ser omitido
list_array[0:-2]
# Out:
# ['one', 4.0, 'Data']

# %%
#mostrar de 2 em 2
#quando omitido o valor final também indica que o slice segue até o ultimo item
list_array[0::2]
# Out:
# ['one', 'Data', 'Intro']

# %% [markdown]
# ---

# %% [markdown]
# #### Range

# %%
#range são usados para criar listas de numeros sequenciais
range(4)
# Out:
# range(0, 4)

# %%
#é possivel utilizar um range como lista
list(range(4))
# Out:
# [0, 1, 2, 3]

# %%
#a linha abaixo cria uma sequencia de numeros que vai de 2 até 4 (o 4 nao incluido)
list(range(2, 4))
# Out:
# [2, 3]

# %% [markdown]
# ---

# %% [markdown]
# #### Tuples

# %%
#tuplas são tipo de dados que são armazenados em conjunto e vinculados.
#tuplas sao criadas utilizando parênteses normais
a_tuple = ("one", "two", "three")
a_tuple
# Out:
# ('one', 'two', 'three')

# %%
#é possivel acessar um valor de uma tupla passando o endereço
a_tuple[1]
# Out:
# 'two'

# %% [markdown]
# Tuples are immutable! For example, if you try to update or delete one value it will return an error

# %%
#não é possivel modificar os dados de uma tupla
a_tuple[1] = "hello"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/zuilpirola/Desktop/DS Solutions/Lab 1 - Solution.ipynb Cell 65 line 2
#       <a href='vscode-notebook-cell:/Users/zuilpirola/Desktop/DS%20Solutions/Lab%201%20-%20Solution.ipynb#Y116sZmlsZQ%3D%3D?line=0'>1</a> #não é possivel modificar os dados de uma tupla
# ----> <a href='vscode-notebook-cell:/Users/zuilpirola/Desktop/DS%20Solutions/Lab%201%20-%20Solution.ipynb#Y116sZmlsZQ%3D%3D?line=1'>2</a> a_tuple[1] = "hello"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#nem deleta-los
del a_tuple[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/zuilpirola/Desktop/DS Solutions/Lab 1 - Solution.ipynb Cell 66 line 2
#       <a href='vscode-notebook-cell:/Users/zuilpirola/Desktop/DS%20Solutions/Lab%201%20-%20Solution.ipynb#Y120sZmlsZQ%3D%3D?line=0'>1</a> #nem deleta-los
# ----> <a href='vscode-notebook-cell:/Users/zuilpirola/Desktop/DS%20Solutions/Lab%201%20-%20Solution.ipynb#Y120sZmlsZQ%3D%3D?line=1'>2</a> del a_tuple[1]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# Adding elements to a tuple creates a new one

# %%
#uma solucao seria criar uma nova tupla a partir de uma existente
a_second_tuple = a_tuple + (23,)
print(a_second_tuple)
#a primeira tupla continua existindo e imutável
print(a_tuple)
# Out:
# ('one', 'two', 'three', 23)
# ('one', 'two', 'three')

# %% [markdown]
# Memory address of each variable

# %%
#é possivel ver o endereço de uma variavel através do id()
#endereço das duas tuplas são diferentes
print(id(a_tuple))
print(id(a_tuple + (23,)))
# Out:
# 4669165120
# 4669816896

# %% [markdown]
# ---

# %% [markdown]
# ### Mapping Types

# %% [markdown]
# #### Dictionary

# %% [markdown]
# A dictionary is a mapping object composed of *keys* and *values* and *keys* need to hashable (lists and dictionaries are not)
#
# For example `{'data': 0, 'science': 0}`

# %%
#criar um dicionário
a_dict = dict()

#imprimar o tipo
print(type(a_dict))
# Out:
# <class 'dict'>

# %%
#outra forma de criar um dicionário é usando as chavetas
a_dict = {}

print(type(a_dict))
# Out:
# <class 'dict'>

# %%
#um dicionário é formada por uma key:value
a_dict = {1: 2}

#print do dicionário
a_dict
# Out:
# {1: 2}

# %%
#para acessar um value através da sua key
print(a_dict[1])
# Out:
# 2

# %%
#dicionário aceitam diversos tipos de values
#as keys precisam ser hashable
a_dict = {'data': 2, 1: 2, 'science': 4}
a_dict
# Out:
# {'data': 2, 1: 2, 'science': 4}

# %% [markdown]
# Access the value of a key

# %%
#acessar um value através de uma key tipo string
a_dict['data']

# %% [markdown]
# Delete entry with the key ```data```

# %%
#é possivel deletar um dado de um dict através da função del
del a_dict['data']

# %%
#print do dicionário
a_dict
# Out:
# {1: 2, 'science': 4}

# %% [markdown]
# ---

# %% [markdown]
# ## Membership Operators

# %%
#operador "in" é uma forma de saber se um dado está ou nao em uma lista
5.0 in [ 1, 2, 3, 4]
# Out:
# False

# %%
#operador in também aceita not
5.0 not in [ 1, 2, 3, 4]
# Out:
# True

# %%
#é possivel testar também se strings estão em listas
'um' in ['um','dois','três']
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# ## Control Flow Tools

# %% [markdown]
# ### For Statements

# %% [markdown]
# ```python
# for <var> in <iterable>:
#     <statement(s)>
# ```

# %% [markdown]
# `iterable` is a collection of objects—for example, a list or tuple. The `statement(s)` in the loop body are denoted by indentation, as with all Python control structures, and are executed once for each item in `iterable`. The loop variable `var` takes on the value of the next element in `iterable` each time through the loop.

# %%
#um for vai interagir com um objeto e retornar todas partes desse objeto
#seja uma lista
for value in [1,2,3,4]:
    print(value)
# Out:
# 1
# 2
# 3
# 4

# %%
#tupla
a = (1,2,3)

#seja uma tupla
for x in a:
    print(x)
# Out:
# 1
# 2
# 3

# %% [markdown]
# #### range is often used as the iterable
#
# ```python
#     for <var> in range(limit):
#         <statement(s)>
# ```

# %%
#quando precisamos criar um for através de um contador utilizamos um range
for value in range(len(list_array)):
    print(value)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### If Statements

# %% [markdown]
# ```python
#     if <expr>:
#         <statement>
#     elif <expr>:
#         <statement>
#     else:
#         <statement>
# ```

# %% [markdown]
# `expr` is an expression evaluated in a Boolean context
#
# `statement` is a valid Python statement, which must be indented

# %%
#o if no python funciona tal qual outras linguagens mas sem a necessidade do uso de "()" ou "{}"
#é obrigatório identar a estrutura do if para que ela aconteça
if 2 > 4:
    print("2 > 4")
else:
    print("2 <= 4")
# Out:
# 2 <= 4

# %% [markdown]
# ### List Comprehensions

# %% [markdown]
# Create lists with elements with a single statement
#
# ```python
# [ expression for a_value in a_collection ]
#
# ```

# %%
#comprehensions é a forma de escrever o for com uma linha
print([ a_value + 10 for a_value in [1,2,3,4,5] ])

#ou

print()
for a_value in [1,2,3,4,5]:
    print(a_value + 10)
# Out:
# [11, 12, 13, 14, 15]
#
# 11
# 12
# 13
# 14
# 15

# %% [markdown]
# List comprehension with conditions
#
# ```python
# [ expression for a_value in a_collection if condition ]
#
# ```

# %%
#é possivel colocar um if dentro de um comprehension
[ a_value + 10 for a_value in [1,2,3,4,5] if a_value >= 3 ]
# Out:
# [13, 14, 15]

# %% [markdown]
# ---

# %% [markdown]
# ## Functions

# %%
#definir o nome da função
def functionName(argument_one, argument_two):
    #comentários sobre a funcao e podem ser acessados via help()
    """
    Comment what it does
    """


    print("do_stuff")

    #retornar valores através da return
    return argument_one + argument_two

# %%
help(functionName)
# Out:
# Help on function functionName in module __main__:
#
# functionName(argument_one, argument_two)
#     Comment what it does

# %%
functionName(1,2)
# Out:
# do_stuff
# 3

# %% [markdown]
# ### Call a function

# %% [markdown]
# ```python
# functionName(argument_one, argument_two)
# ```

# %%
#funcao que faz soma de ddois valores
def soma(x, y):
    """
    Return the sum between x and y
    """

    return x + y

# %%
soma(2, 4)
# Out:
# 6

# %% [markdown]
# ### Built-in Functions
#
# We have already used some. But there are more:
#
# https://docs.python.org/3/library/functions.html

# %% [markdown]
# ## Code Standards

# %% [markdown]
# [PEP 8: Function and Variable Names](https://www.python.org/dev/peps/pep-0008/#function-and-variable-names)
#
# **Summary**
#  - Use Snake case in functions and variables, lowercase with words separated by underscores as necessary to improve readability
#      - data_science
#
#
#  - For constants use all capital letters with underscores separating words
#      - DATA_SCIENCE
#
#
#  - Use CapWords convention for classes
#      - DataScience

# %% [markdown]
# # Challenges - Part I
#
# **Cosine similarity from scratch**
#
#
# ## Question 1/6
#
# The dot product between two vectors $v1$ e $v2$ of size $n$ is defined as:
#
# $$\sum_{i=1}^n v1_i . v2_i $$
#
# Create a `for` loop necessary to compute the dot product between any two vectors of the same size.

# %%
# SOLUTION 1

#criando os dois vetores
v1 = [1,2,3,4]
v2 = [3,2,5,4]

#variavel do produto dos vetores
dot_prod = 0

#para cada elemento em v1
for i in range(len(v1)):
    #usar o valor de i para acessar os endereços dos vetores
    dot_prod += v1[i]*v2[i]

#print do produto
print(dot_prod)
# Out:
# 38

# %%
# SOLUTION 2

#criando os dois vetores
v1 = [1,2,3,4]
v2 = [3,2,5,4]

res = []
#so faz o produto se os vetores forem de igual tamanho
if len(v1) == len(v2): # validar se os vetores são do mesmo tamanho
    for i in range(len(v1)): # aqui utilizamos um ciclo for tradicional
        res.append(v1[i]*v2[i])
    res = sum(res)

print('the dot product of both vectors is', res)
# Out:
# the dot product of both vectors is 38

# %% [markdown]
# ## Question 2/6
#
# Try using the built-in function `zip`. Pass vectors `v1` and `v2` as parameters.
#
# **Note.** `zip` produces an object of class `zip`, but we can cast it as a `list` using the built-in function `list()` on that object

# %%
# defina uma variável x e instancie com a aplicação da função zip(v1,v2)
x = zip(v1,v2)

# aplique a função list à variável x para ver o conteúdo do resultado
list(x)
# Out:
# [(1, 3), (2, 2), (3, 5), (4, 4)]

# %% [markdown]
# Based on the result obtained explain what the `zip`function does.

# %%
# funcao zip cria uma lista de tuplas a partir de listas.
#As tuplas sao formadas a partir do primeiro item de uma lista com o primeiro item da outra e assim sucessivamente até o final.
#quando as listas possuem tamanhos diferentes a lista final do zip terá sempre o tamanho da menor lista.
#ela vai truncar os valores excedentes

# %% [markdown]
# ---
# ## Question 3/6
#
# Try using the built-in funcion `zip()` to compute the dot product in single line of code.
#
# - **Hint 1:** use a list comprehension
# - **Hint 2:** use the built-in function `sum()` to obtain the sum of all values of a list

# %%
#usa-se o zip para juntar as duas listas (desprezando os valores excedentes)
#utiliza os endereços para acessar os itens da tupla e faze-se a multiplicação
res = sum([item[0]*item[1] for item in zip(v1,v2)])
res
# Out:
# 38

# %% [markdown]
# ---
# ## Question 4/6
#
# The norm of a vector (its magnitude) is defined as:
#
# $$ \lVert x \rVert = \sqrt{\sum_{i=1}^n x_i^2}$$
#
# Write a for loop that computes a norm of a given vector $v$.

# %%
# SOLUTION v1

#variavel para calcular o total
total = 0
#looping que corre todos os valores de v1
for item in range(len(v1)):
    #calculo do quadrado dos itens em v1
    total += v1[item]**2

#a raiz quadrada da soma dos quadrados
total**0.5
# Out:
# 5.477225575051661

# %%
# SOLUTION v2 - forma Pythonica

#usando math
import math

#iniciar v1
v1 = [1,2,3,4]

#usa-se comprehension junto com o math.sqrt (raiz quadrada)
norm = math.sqrt(sum([item**2 for item in v1]))
norm
# Out:
# 5.477225575051661

# %% [markdown]
# ## Question 5/6
#
# Recall how to create a funcion:
#
# ```python
# def name_of_the_function(list of arguments):
#     do something
#     ...
#     return the_result
# ```
#
# 1. Define a function that computes the dot product of two vectors $v1$ e $v2$
#
# 2. Define a function that computes the norm of a vector $v$

# %%
#conversao dos comandos escritos acima em funcoes

#funcao para produto do dois vetores
def dot_product(v1, v2):
    if len(v1) == len(v2):
        res = sum([item[0]*item[1] for item in zip(v1,v2)])
    else:
        res = -1
    return res



#funcao para normalizar um vetor
def norm_l2(v):
    return math.sqrt(sum([item**2 for item in v]))

# %%
# produto entre v1 e v2
dot_product(v1, v2)
# Out:
# 38

# %%
#norm de v1
norm_l2(v1)
# Out:
# 5.477225575051661

# %%
#norm de v2
norm_l2(v2)
# Out:
# 7.3484692283495345

# %% [markdown]
# ## Question 6/6
#
# In Data Science there is this famous measure of similarity called cosine similarity.
#
# Given two vectors $v1$ e $v2$, it is defined as:
#
# $$
#   cos(v1, v2) = \frac{v1 . v2}{\lVert v1 \rVert \times \lVert v2 \rVert}
# $$
#
# Using the above functions, define a new one that computes this similarity.

# %%
#funcao que agrega as duas funcoes juntas
def sim_cos(v1, v2):
    return dot_product(v1,v2)/ (norm_l2(v1)*norm_l2(v2))

sim_cos(v1, v2)
# Out:
# 0.9441175904999112

# %% [markdown]
# # Calculator Challenge
# Write a Python function that accepts three parameters.
# - The first parameter is a numeric value.
# - The second is one of the following mathematical operators: +, -, /, or .
# - The third parameter will also be a numeric value
#
# The function should perform a calculation and return the results.
#
# For example, parameters `(2.5, '.', 3)` should return `7.5`.

# %%
# Solution

#cria-se uma funcao que recebe 3 parametros
def calculator(int1 :float, operation :str, int2:float):
    """
    performs some calculation
    """
    #com base no operador muda a operação
    if operation == '+':
        return int1+int2
    elif operation == '-':
        return int1-int2
    elif operation == '/':
        return int1/int2
    else:
        return int1*int2

# %% [markdown]
# # Extra Challenges
#
# Write a list comprehension that filters an existing list of strings:
#
# 1. firstly, the ones with more than four letters
# 2. secondly, the ones with at least two different vowels
# 3. all the above

# %%
#solução 1
#define as palavras
my_words = ['pyramid', 'car', 'quiet', 'data', 'read']

#corre todos as palavras e printa aquelas quie tem len()>4
[item for item in my_words if len(item) > 4]
# Out:
# ['pyramid', 'quiet']

# %%
#Solução 2

#cria a funcao de contagem de vogais
def count_distinct_vowels(word):
    #definir as vogais
    vowels = ['a','e','i','o', 'u']
    #cnt é um set das vogais que uma palavra possui
    cnt = set([letter for letter in word if letter in vowels])
    #retorna a quantidade de vogais
    return len(cnt)


# Fazendo sem comprehension e em uma linha par
[item for item in my_words if count_distinct_vowels(item) >= 2]
# Out:
# ['pyramid', 'quiet', 'read']

# %%
# Solution 3
#palavras maiores que 4 caracteres e com duas ou mais vogais
[item for item in my_words if len(item) > 4 and count_distinct_vowels(item) >= 2]
# Out:
# ['pyramid', 'quiet']
